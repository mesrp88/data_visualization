# %% [markdown]
# <a href="https://colab.research.google.com/github/mesrp88/data_visualization/blob/main/barplot_and_scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy import arange

# %%
url='/content/fandango_scores.csv'
norm_reviews =pd.read_csv(url)
num_cols = ['RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']

# %%
norm_reviews=norm_reviews[num_cols]
norm_reviews.head()
# Out:
#    RT_user_norm  Metacritic_user_nom  ...  Fandango_Ratingvalue  Fandango_Stars
# 0           4.3                 3.55  ...                   4.5             5.0
# 1           4.0                 3.75  ...                   4.5             5.0
# 2           4.5                 4.05  ...                   4.5             5.0
# 3           4.2                 2.35  ...                   4.5             5.0
# 4           1.4                 1.70  ...                   3.0             3.5
#
# [5 rows x 5 columns]

# %%
bar_heights = norm_reviews[num_cols].iloc[0].values
bar_positions = arange(5) + 0.75
bar_heights
# Out:
# array([4.3 , 3.55, 3.9 , 4.5 , 5.  ])

# %%
bar_positions
# Out:
# array([0.75, 1.75, 2.75, 3.75, 4.75])

# %%
fig, ax= plt.subplots()
ax.bar(x= bar_positions, height= bar_heights, width=0.5, align='edge')
tick_positions = range(1,6)
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation=90)
plt.show()

# %%
fig, ax= plt.subplots()
ax.bar(x= bar_positions, height= bar_heights, width=0.5, align='edge')
tick_positions = range(1,6)
ax.set_xticks(tick_positions)
ax.set_xticklabels(num_cols, rotation=90)
ax.set_xlabel('Rating Source')
ax.set_ylabel('Average Rating')
ax.set_title('Average User Rating For Avengers: Age of Ultron (2015)')
plt.show()

# %%
bar_widths = norm_reviews[num_cols].iloc[0].values
bar_positions = arange(5) + 0.75
tick_positions = range(1,6)
fig, ax=plt.subplots()
ax.barh(y=bar_positions,width=bar_widths, height=0.5, align='edge')
ax.set_yticks(tick_positions)
ax.set_yticklabels(num_cols)
ax.set_ylabel('Rating Source')
ax.set_xlabel('Average Rating')
ax.set_title("Average User Rating For Avengers: Age of Ultron (2015)")
plt.show()

# %% [markdown]
# Scatter Plot

# %%
fig, ax= plt.subplots()
ax.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax.set_xlabel("Fandango")
ax.set_ylabel('Rotten Tomatoes')
plt.show()

# %%
fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
reviews = pd.read_csv('fandango_scores.csv')
cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue', 'Fandango_Stars']
norm_reviews = reviews[cols]
ax1.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax1.set_xlabel('Fandango')
ax1.set_ylabel('Rotten Tomatoes')

ax2.scatter(norm_reviews['RT_user_norm'], norm_reviews['Fandango_Ratingvalue'])
ax2.set_xlabel('Rotten Tomatoes')
ax2.set_ylabel('Fandango')
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

ax1.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['RT_user_norm'])
ax1.set_xlabel('Fandango')
ax1.set_ylabel('Rotten Tomatoes')
ax1.set_xlim(0,5)
ax1.set_ylim(0,5)

ax2.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['Metacritic_user_nom'])
ax2.set_ylabel('Metacritic')
ax2.set_xlabel('Fandango')
ax2.set_xlim(0,5)
ax2.set_ylim(0,5)

ax3.scatter(norm_reviews['Fandango_Ratingvalue'], norm_reviews['IMDB_norm'])
ax3.set_xlabel('Fandango')
ax3.set_ylabel('IMDB')
ax3.set_xlim(0,5)
ax3.set_ylim(0,5)

plt.show()
